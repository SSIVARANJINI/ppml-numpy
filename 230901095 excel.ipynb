# %%
import pandas as pd
pd.set_option('display.max_columns',6)
print("original data:\n")
df=pd.read_excel("/Users/Student/Downloads/pandas (3).xlsx")
print(df)
# Out:
# original data:
#
#     Unnamed: 0  Emp ID Name Prefix  ...       Mother's Name  \
# 0            0  677509        Drs.  ...        Helen Walker
# 1            1  940761         Ms.  ...       Judy Robinson
# 2            2  428945         Dr.  ...  Stephanie Robinson
# 3            3  408351        Drs.  ...      Michelle Evans
# 4            4  193819         Mr.  ...   Elizabeth Russell
# 5            5  499687         Mr.  ...        Laura Bailey
# 6            6  539712         Ms.  ...          Judy Baker
# 7            7  380086        Mrs.  ...    Katherine Murphy
# 8            8  477616        Hon.  ...       Lillian Young
# 9            9  162402        Hon.  ...  Christina Peterson
# 10          10  231469         Mr.  ...     Michelle Flores
# 11          11  153989       Prof.  ...    Sharon Alexander
# 12          12  386158        Mrs.  ...          Maria King
# 13          13  301576        Hon.  ...     Margaret Watson
# ...

# %%
f=df['First Name'].str.strip()
f.to_excel("/Users/student/Downloads/pandas (3).xlsx")
print("\n Replace value:")
k=df.fillna(method='pad')
print(k)
print("\nUpdate list\n")
k.to_excel("/Users/student/Downloads/pandas (3).xlsx")
# Out:
#  Replace value:
#     Unnamed: 0  Emp ID Name Prefix  ...       Mother's Name  \
# 0            0  677509        Drs.  ...        Helen Walker
# 1            1  940761         Ms.  ...       Judy Robinson
# 2            2  428945         Dr.  ...  Stephanie Robinson
# 3            3  408351        Drs.  ...      Michelle Evans
# 4            4  193819         Mr.  ...   Elizabeth Russell
# 5            5  499687         Mr.  ...        Laura Bailey
# 6            6  539712         Ms.  ...          Judy Baker
# 7            7  380086        Mrs.  ...    Katherine Murphy
# 8            8  477616        Hon.  ...       Lillian Young
# 9            9  162402        Hon.  ...  Christina Peterson
# 10          10  231469         Mr.  ...     Michelle Flores
# 11          11  153989       Prof.  ...    Sharon Alexander
# 12          12  386158        Mrs.  ...          Maria King
# 13          13  301576        Hon.  ...     Margaret Watson
# ...

# %%
print("\n Drop one particular column and its values:\n")
k.drop(['Gender'],axis=1,inplace=True)
print(k)
print("\n updated list\n")
k.to_excel("/Users/student/Downloads/pandas (3).xlsx")
# Out:
#  Drop one particular column and its values:
#
#     Unnamed: 0  Emp ID Name Prefix  ...       Mother's Name  \
# 0            0  677509        Drs.  ...        Helen Walker
# 1            1  940761         Ms.  ...       Judy Robinson
# 2            2  428945         Dr.  ...  Stephanie Robinson
# 3            3  408351        Drs.  ...      Michelle Evans
# 4            4  193819         Mr.  ...   Elizabeth Russell
# 5            5  499687         Mr.  ...        Laura Bailey
# 6            6  539712         Ms.  ...          Judy Baker
# 7            7  380086        Mrs.  ...    Katherine Murphy
# 8            8  477616        Hon.  ...       Lillian Young
# 9            9  162402        Hon.  ...  Christina Peterson
# 10          10  231469         Mr.  ...     Michelle Flores
# 11          11  153989       Prof.  ...    Sharon Alexander
# 12          12  386158        Mrs.  ...          Maria King
# 13          13  301576        Hon.  ...     Margaret Watson
# ...
